# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import os
#from langchain.document_loaders import PyPDFLoader, UnstructuredPDFLoader, PyPDFium2Loader
from langchain.document_loaders import PyPDFDirectoryLoader, DirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from pathlib import Path
import random

# %%
## Input data directory
data_dir = "cureus"
inputdirectory = Path(f"./data_input/{data_dir}")
## This is where the output csv files will be written
out_dir = data_dir
outputdirectory = Path(f"./data_output/{out_dir}")

# %% [markdown]
# # Load Documents

# %% [markdown]
# Load

# %%
## PDF Loader
# loader = PyPDFDirectoryLoader(Path(f"./data_input"))

## File txt Loader
loader = DirectoryLoader(inputdirectory, show_progress=True)
documents = loader.load()
# Out:
# 100%|██████████| 1/1 [00:06<00:00,  6.79s/it]

# %% [markdown]
# 定義分割器

# %%
'''
chunk_size：每個段落的最大字數
chunk_overlap：每個段落的重疊字數，用於保持上下文連貫
length_function：用於計算文本長度的函數，這裡使用 Python 的內建函數 len
is_separator_regex：檢測段落分隔符的正則表達式，這裡設置為 False，表示不使用正則表達式，而是使用固定的 chunk_size 和 chunk_overlap 來分割文本
'''
splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=150,
    length_function=len,
    is_separator_regex=False,
)

# %% [markdown]
# 分割文件

# %%
pages = splitter.split_documents(documents)
print("Number of chunks = ", len(pages))

print(pages[0].page_content)
# Out:
# Number of chunks =  3
# In a village on a hillside lived a boy named Peter, whose parents were sheep farmers. Everybody in the village had to take turns looking after the sheep. At 10, Peter was regarded as old enough to take his turn at shepherding.
#
# However, Peter found it very dull on the hillside with only sheep for company. So he’d look for ways to amuse himself: running up rocks, climbing trees and even chasing sheep. Unfortunately, he still felt bored. Then a brilliant idea crossed his mind. He climbed to the top of the tallest tree, shouting towards the village: “Wolf! Wolf! Wooolf! Woohoolf!”
#
# One of the villagers heard him and informed all the other people, who got together and armed themselves with axes and hoes. They ran out of the village to chase away the wolf and save their herd. However, when they got there, all they found was Peter perched high up in his tree with the sheep grazing peacefully nearby. Everyone was very annoyed with him.
#
# For a while life went on again as usual. As time went by, people forgot about the incident. Until one day, Peter repeated the same trick, enjoying the attention it garnered. He picked up some sticks, and running through where the sheep were grazing, he started hitting the sticks together, shouting: “Wolf! Wolf! Wooolf! Woohoolf! Woohoohoooolf!”

# %% [markdown]
# # Create a dataframe of all the chunks

# %%
from helpers.df_helpers import documents2Dataframe

# %%
df = documents2Dataframe(pages)
print(df.shape)
df.head()
# Out:
# (3, 3)
#                                                 text  \
# 0  In a village on a hillside lived a boy named P...
# 1  Sure enough, somebody in the village heard, an...
# 2  This time, nobody believed that there was real...
#
#                                           source  \
# 0  data_input\cureus\cureus-0015-00000040274.txt
# 1  data_input\cureus\cureus-0015-00000040274.txt
# 2  data_input\cureus\cureus-0015-00000040274.txt
#
#                            chunk_id
# 0  1eaefb29ecfb40cc82c4afbffcb334d6
# 1  0196b7c7a6e34038aff70f7476f3429b
# 2  a3763b0c0dd84c3abe7346c9617d2551

# %% [markdown]
# ## Extract Concepts

# %%
## This function uses the helpers/prompt function to extract concepts from text
from helpers.df_helpers import df2Graph
from helpers.df_helpers import graph2Df

# %% [markdown]
# If regenerate is set to True then the dataframes are regenerated and Both the dataframes are written in the csv format so we dont have to calculate them again.
#
#         dfne = dataframe of edges
#
#         df = dataframe of chunks
#
#
# Else the dataframes are read from the output directory

# %%
## To regenerate the graph with LLM, set this to True
#regenerate = False
regenerate = True

if regenerate:
    concepts_list = df2Graph(df, model='zephyr:latest')
    dfg1 = graph2Df(concepts_list)
    if not os.path.exists(outputdirectory):
        os.makedirs(outputdirectory)
    
    dfg1.to_csv(outputdirectory/"graph_1.csv", sep="|", index=False)
    df.to_csv(outputdirectory/"chunks_1.csv", sep="|", index=False)
else:
    dfg1 = pd.read_csv(outputdirectory/"graph.csv", sep="|")
# Out:
# [
#    {
#        "node_1": "Peter",
#        "node_2": "Boredom",
#        "edge": "At a young age, Peter found shepherding to be dull and uninteresting. He struggled with finding ways to amuse himself while on duty."
#    },
#    {
#        "node_1": "Peter",
#        "node_2": "Creativity",
#        "edge": "In order to escape boredom, Peter came up with innovative ways to entertain himself while on shepherding duty."
#    },
#    {
#        "node_1": "Peter",
#        "node_2": "Ambiguity",
#        "edge": "Initially, when villagers heard Peter's wolf cry, they mistakenly assumed it was a real wolf threat."
#    },
#    {
#        "node_1": "Villagers",
#        "node_2": "Irritation",
#        "edge": "After the first incident, the other villagers became annoyed with Peter's false alarms."
#    },
#    {
#        "node_1": "Peter",
#        "node_2": "Attention-seeking",
#        "edge": "Peter enjoyed receiving attention from his false wolf cries and continued to do so in the future."
#    }
# ][
#   {
#     "node_1": "Peter",
#     "node_2": "village",
#     "edge": "lives in the village"
#   },
#   {
#     "node_1": "sheep",
#     "node_2": "Peter",
#     "edge": "in possession of Peter"
#   },
#   {
#     "node_1": "wolf",
#     "node_2": "sheep",
#     "edge": "attacks the sheep"
#   },
#   {
#     "node_1": "Peter",
#     "node_2": "tree",
#     "edge": "climbs a tree to observe the wolf attacking the sheep"
#   },
#   {
#     "node_1": "villager",
#     "node_2": "old man",
#     "edge": "hears Peter's shouting"
#   },
#   {
#     "node_1": "Peter",
#     "node_2": "sheep",
#     "edge": "wants to save the sheep from the wolf"
#   },
#   {
#     "node_1": "Peter",
#     "node_2": "village",
#     "edge": "receives a severe telling-off for his wrongdoing in the village"
#   }
# ][
#    {
#        "node_1": "wolf",
#        "node_2": "sheep",
#        "edge": "The wolf took one of the fattest sheep."
#    },
#    {
#        "node_1": "villagers",
#        "node_2": "dead sheep's bodies",
#        "edge": "People found dead sheep's bodies strewn all over the hillside."
#    },
#    {
#        "node_1": "Peter",
#        "node_2": "bell",
#        "edge": "When the wolf really attacked, Peter rang his bell crying ‘Wolf!’"
#    },
#    {
#        "node_1": "men",
#        "node_2": "wolf",
#        "edge": "The men did not come out when Peter cried 'Wolf!' because they thought that he was just playing a trick again."
#    }
# ]

# %%
dfg1.replace("", np.nan, inplace=True)
dfg1.dropna(subset=["node_1", "node_2", 'edge'], inplace=True)
dfg1['count'] = 4 
## Increasing the weight of the relation to 4. 
## We will assign the weight of 1 when later the contextual proximity will be calculated.  
print(dfg1.shape)
dfg1.head()
# Out:
# (16, 5)
#       node_1             node_2  \
# 0      peter            boredom
# 1      peter         creativity
# 2      peter          ambiguity
# 3  villagers         irritation
# 4      peter  attention-seeking
#
#                                                 edge  \
# 0  At a young age, Peter found shepherding to be ...
# 1  In order to escape boredom, Peter came up with...
# 2  Initially, when villagers heard Peter's wolf c...
# 3  After the first incident, the other villagers ...
# 4  Peter enjoyed receiving attention from his fal...
#
#                            chunk_id  count
# 0  1eaefb29ecfb40cc82c4afbffcb334d6      4
# 1  1eaefb29ecfb40cc82c4afbffcb334d6      4
# 2  1eaefb29ecfb40cc82c4afbffcb334d6      4
# 3  1eaefb29ecfb40cc82c4afbffcb334d6      4
# 4  1eaefb29ecfb40cc82c4afbffcb334d6      4

# %% [markdown]
# ## Calculating contextual proximity

# %%
def contextual_proximity(df: pd.DataFrame) -> pd.DataFrame:
    ## Melt the dataframe into a list of nodes
    dfg_long = pd.melt(
        df, id_vars=["chunk_id"], value_vars=["node_1", "node_2"], value_name="node"
    )
    dfg_long.drop(columns=["variable"], inplace=True)
    # Self join with chunk id as the key will create a link between terms occuring in the same text chunk.
    dfg_wide = pd.merge(dfg_long, dfg_long, on="chunk_id", suffixes=("_1", "_2"))
    # drop self loops
    self_loops_drop = dfg_wide[dfg_wide["node_1"] == dfg_wide["node_2"]].index
    dfg2 = dfg_wide.drop(index=self_loops_drop).reset_index(drop=True)
    ## Group and count edges.
    dfg2 = (
        dfg2.groupby(["node_1", "node_2"])
        .agg({"chunk_id": [",".join, "count"]})
        .reset_index()
    )
    dfg2.columns = ["node_1", "node_2", "chunk_id", "count"]
    dfg2.replace("", np.nan, inplace=True)
    dfg2.dropna(subset=["node_1", "node_2"], inplace=True)
    # Drop edges with 1 count
    dfg2 = dfg2[dfg2["count"] != 1]
    dfg2["edge"] = "contextual proximity"
    return dfg2


dfg2 = contextual_proximity(dfg1)
dfg2.tail()
# Out:
#     node_1     node_2                                           chunk_id  \
# 110   wolf        men  a3763b0c0dd84c3abe7346c9617d2551,a3763b0c0dd84...
# 112   wolf      peter  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 113   wolf      sheep  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 115   wolf    village  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 117   wolf  villagers  a3763b0c0dd84c3abe7346c9617d2551,a3763b0c0dd84...
#
#      count                  edge
# 110      2  contextual proximity
# 112      7  contextual proximity
# 113      5  contextual proximity
# 115      2  contextual proximity
# 117      2  contextual proximity

# %% [markdown]
# ### Merge both the dataframes

# %%
dfg = pd.concat([dfg1, dfg2], axis=0)
dfg = (
    dfg.groupby(["node_1", "node_2"])
    .agg({"chunk_id": ",".join, "edge": ','.join, 'count': 'sum'})
    .reset_index()
)
dfg
# Out:
#                  node_1               node_2  \
# 0             ambiguity                peter
# 1     attention-seeking                peter
# 2                  bell                 wolf
# 3               boredom                peter
# 4            creativity                peter
# 5   dead sheep's bodies                 wolf
# 6            irritation                peter
# 7                   men                 wolf
# 8               old man                peter
# 9               old man                sheep
# 10              old man              village
# 11                peter            ambiguity
# 12                peter    attention-seeking
# 13                peter                 bell
# 14                peter              boredom
# 15                peter           creativity
# 16                peter           irritation
# 17                peter              old man
# 18                peter                sheep
# 19                peter                 tree
# 20                peter              village
# 21                peter             villager
# 22                peter            villagers
# 23                peter                 wolf
# 24                sheep              old man
# 25                sheep                peter
# 26                sheep                 tree
# 27                sheep              village
# 28                sheep             villager
# 29                sheep                 wolf
# 30                 tree                peter
# 31                 tree                sheep
# 32                 tree              village
# 33              village              old man
# 34              village                peter
# 35              village                sheep
# 36              village                 tree
# 37              village             villager
# 38              village                 wolf
# 39             villager              old man
# 40             villager                peter
# 41             villager                sheep
# 42             villager              village
# 43            villagers  dead sheep's bodies
# 44            villagers           irritation
# 45            villagers                peter
# 46            villagers                 wolf
# 47                 wolf                 bell
# 48                 wolf  dead sheep's bodies
# 49                 wolf                  men
# 50                 wolf                peter
# 51                 wolf                sheep
# 52                 wolf              village
# 53                 wolf            villagers
#
#                                              chunk_id  \
# 0   1eaefb29ecfb40cc82c4afbffcb334d6,1eaefb29ecfb4...
# 1   1eaefb29ecfb40cc82c4afbffcb334d6,1eaefb29ecfb4...
# 2   a3763b0c0dd84c3abe7346c9617d2551,a3763b0c0dd84...
# 3   1eaefb29ecfb40cc82c4afbffcb334d6,1eaefb29ecfb4...
# 4   1eaefb29ecfb40cc82c4afbffcb334d6,1eaefb29ecfb4...
# 5   a3763b0c0dd84c3abe7346c9617d2551,a3763b0c0dd84...
# 6   1eaefb29ecfb40cc82c4afbffcb334d6,1eaefb29ecfb4...
# 7   a3763b0c0dd84c3abe7346c9617d2551,a3763b0c0dd84...
# 8   0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 9   0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 10  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 11  1eaefb29ecfb40cc82c4afbffcb334d6,1eaefb29ecfb4...
# 12  1eaefb29ecfb40cc82c4afbffcb334d6,1eaefb29ecfb4...
# 13                   a3763b0c0dd84c3abe7346c9617d2551
# 14  1eaefb29ecfb40cc82c4afbffcb334d6,1eaefb29ecfb4...
# 15  1eaefb29ecfb40cc82c4afbffcb334d6,1eaefb29ecfb4...
# 16  1eaefb29ecfb40cc82c4afbffcb334d6,1eaefb29ecfb4...
# 17  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 18  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 19  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 20  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 21  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 22  1eaefb29ecfb40cc82c4afbffcb334d6,1eaefb29ecfb4...
# 23  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 24  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 25  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 26  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 27  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 28  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 29  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 30  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 31  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 32  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 33  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 34  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 35  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 36  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 37  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 38  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 39                   0196b7c7a6e34038aff70f7476f3429b
# 40  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 41  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 42  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 43                   a3763b0c0dd84c3abe7346c9617d2551
# 44                   1eaefb29ecfb40cc82c4afbffcb334d6
# 45  1eaefb29ecfb40cc82c4afbffcb334d6,1eaefb29ecfb4...
# 46  a3763b0c0dd84c3abe7346c9617d2551,a3763b0c0dd84...
# 47  a3763b0c0dd84c3abe7346c9617d2551,a3763b0c0dd84...
# 48  a3763b0c0dd84c3abe7346c9617d2551,a3763b0c0dd84...
# 49  a3763b0c0dd84c3abe7346c9617d2551,a3763b0c0dd84...
# 50  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 51  0196b7c7a6e34038aff70f7476f3429b,a3763b0c0dd84...
# 52  0196b7c7a6e34038aff70f7476f3429b,0196b7c7a6e34...
# 53  a3763b0c0dd84c3abe7346c9617d2551,a3763b0c0dd84...
#
#                                                  edge  count
# 0                                contextual proximity      4
# 1                                contextual proximity      4
# 2                                contextual proximity      2
# 3                                contextual proximity      4
# 4                                contextual proximity      4
# 5                                contextual proximity      2
# 6                                contextual proximity      4
# 7   The men did not come out when Peter cried 'Wol...      6
# 8                                contextual proximity      5
# 9                                contextual proximity      3
# 10                               contextual proximity      2
# 11  Initially, when villagers heard Peter's wolf c...      8
# 12  Peter enjoyed receiving attention from his fal...      8
# 13  When the wolf really attacked, Peter rang his ...      4
# 14  At a young age, Peter found shepherding to be ...      8
# 15  In order to escape boredom, Peter came up with...      8
# 16                               contextual proximity      4
# 17                               contextual proximity      5
# 18  wants to save the sheep from the wolf,contextu...     20
# 19  climbs a tree to observe the wolf attacking th...      9
# 20  lives in the village,receives a severe telling...     18
# 21                               contextual proximity      5
# 22                               contextual proximity      5
# 23                               contextual proximity      7
# 24                               contextual proximity      3
# 25        in possession of Peter,contextual proximity     20
# 26                               contextual proximity      3
# 27                               contextual proximity      6
# 28                               contextual proximity      3
# 29                               contextual proximity      5
# 30                               contextual proximity      5
# 31                               contextual proximity      3
# 32                               contextual proximity      2
# 33                               contextual proximity      2
# 34                               contextual proximity     10
# 35                               contextual proximity      6
# 36                               contextual proximity      2
# 37                               contextual proximity      2
# 38                               contextual proximity      2
# 39                             hears Peter's shouting      4
# 40                               contextual proximity      5
# 41                               contextual proximity      3
# 42                               contextual proximity      2
# 43  People found dead sheep's bodies strewn all ov...      4
# 44  After the first incident, the other villagers ...      4
# 45                               contextual proximity      5
# 46                               contextual proximity      2
# 47                               contextual proximity      2
# 48                               contextual proximity      2
# 49                               contextual proximity      2
# 50                               contextual proximity      7
# 51  attacks the sheep,The wolf took one of the fat...     13
# 52                               contextual proximity      2
# 53                               contextual proximity      2

# %% [markdown]
# ## Calculate the NetworkX Graph

# %%
nodes = pd.concat([dfg['node_1'], dfg['node_2']], axis=0).unique()
nodes.shape
# Out:
# (16,)

# %%
import networkx as nx

# %%
G = nx.Graph()

## Add nodes to the graph
for node in nodes:
    G.add_node(
        str(node)
    )

## Add edges to the graph
for index, row in dfg.iterrows():
    G.add_edge(
        str(row["node_1"]),
        str(row["node_2"]),
        title=row["edge"],
        weight=row['count']/4
    )

# %%
print(G)
# Out:
# Graph with 16 nodes and 29 edges

# %% [markdown]
# ### Calculate communities for coloring the nodes

# %%
communities_generator = nx.community.girvan_newman(G)
top_level_communities = next(communities_generator)
next_level_communities = next(communities_generator)
communities = sorted(map(sorted, next_level_communities))
print("Number of Communities = ", len(communities))
print(communities)
# Out:
# Number of Communities =  3
# [['ambiguity', 'attention-seeking', 'boredom', 'creativity', 'old man', 'peter', 'sheep', 'tree', 'village', 'villager'], ['bell', 'men', 'wolf'], ["dead sheep's bodies", 'irritation', 'villagers']]

# %% [markdown]
# ### Create a dataframe for community colors

# %%
import seaborn as sns
palette = "hls"

## Now add these colors to communities and make another dataframe
def colors2Community(communities) -> pd.DataFrame:
    ## Define a color palette
    p = sns.color_palette(palette, len(communities)).as_hex()
    random.shuffle(p)
    rows = []
    group = 0
    for community in communities:
        color = p.pop()
        group += 1
        for node in community:
            rows += [{"node": node, "color": color, "group": group}]
    df_colors = pd.DataFrame(rows)
    return df_colors


colors = colors2Community(communities)
colors
# Out:
#                    node    color  group
# 0             ambiguity  #57db5f      1
# 1     attention-seeking  #57db5f      1
# 2               boredom  #57db5f      1
# 3            creativity  #57db5f      1
# 4               old man  #57db5f      1
# 5                 peter  #57db5f      1
# 6                 sheep  #57db5f      1
# 7                  tree  #57db5f      1
# 8               village  #57db5f      1
# 9              villager  #57db5f      1
# 10                 bell  #db5f57      2
# 11                  men  #db5f57      2
# 12                 wolf  #db5f57      2
# 13  dead sheep's bodies  #5f57db      3
# 14           irritation  #5f57db      3
# 15            villagers  #5f57db      3

# %% [markdown]
# ### Add colors to the graph

# %%
for index, row in colors.iterrows():
    G.nodes[row['node']]['group'] = row['group']
    G.nodes[row['node']]['color'] = row['color']
    G.nodes[row['node']]['size'] = G.degree[row['node']]

# %%
from pyvis.network import Network

graph_output_directory = "./docs/index1.html"

net = Network(
    notebook=False,
    # bgcolor="#1a1a1a",
    cdn_resources="remote",
    height="900px",
    width="100%",
    select_menu=True,
    # font_color="#cccccc",
    filter_menu=False,
)

net.from_nx(G)
# net.repulsion(node_distance=150, spring_length=400)
net.force_atlas_2based(central_gravity=0.015, gravity=-31)
# net.barnes_hut(gravity=-18100, central_gravity=5.05, spring_length=380)
net.show_buttons(filter_=["physics"])

#net.show(graph_output_directory, notebook=False)
net.show(graph_output_directory)
